# %% [markdown]
# ## Using Doc2Vec to find potentials users to answer a novel question
#
# 1. Get the data
# 2. Split the data into train and test
# <br/><br/>
# 3. Using all the questions in the training set, train a Doc2Vec model.
# 4. For all the users, compute a vector represenatation for the user from the questions that he has asked in the system using Doc2Vec. datastructure:(userid, vecRepresentation)
# 5. For a novel question, compute the vector representation.
# 6. Return the nearest neighbour from (4)
# <br/><br/>
# 7. Evaluate the result.

# %% [markdown]
# # Get the data

# %%
#Import Libraries
import xml.etree.ElementTree
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import re
import matplotlib.pyplot as plt
import math 
import time
from nltk import FreqDist
from cStringIO import StringIO

#Get root tag of XML
e = xml.etree.ElementTree.parse('../data/android.meta.stackexchange.com.backup/Posts.xml').getroot()
u = xml.etree.ElementTree.parse('../data/android.meta.stackexchange.com.backup/Users.xml').getroot()

stop_words = set(stopwords.words('english'))

# %%
#Functions

def remove_html_tags(text):
    if text==None:
        return ""
    text=text.encode('utf-8')
    p=re.compile('<[^>]*>|\n')
    return p.sub(" ", text)
    
def clean_tags(text):
    if text==None:
        return ""
    text=text.encode('utf-8')
    p=re.compile('<|>')
    return p.sub(" ", text)

def get_alpha(x):
    x = 0.25 * (abs(x)-5)
    return 1 / (1 + math.exp(-x))

def get_posts(user_id):
    rows = e.findall('.//row[@OwnerUserId="'+ user_id +'"][@PostTypeId="1"]')
    textual_content = ""
    
    for row in rows:
        content = remove_html_tags(row.get('Body'))
        content += remove_html_tags(row.get('Title'))
        content += clean_tags(row.get('Tags'))
        textual_content += content  
        
    return textual_content,get_alpha(len(rows))

def get_ground_truth(question_id):
    # Get the users who answered the question.
    rows = e.findall('.//row[@ParentId="'+ str(question_id) +'"][@PostTypeId="2"]')
    content = []
    for row in rows:
        if (row.get('OwnerUserId') != None):
            content.append(int(row.get('OwnerUserId')))
    return content

def get_epoch(t):
    pattern = '%Y-%m-%dT%H:%M:%S.%f'
    epoch = int(time.mktime(time.strptime(t, pattern)))
    return epoch
    
def get_prior(user_id, question_id):
    user_time  = last_access[user_id]
    que_time = time_of_question[question_id]
    return 1
#     return math.exp(-np.abs(que_time - user_time) / 86400) 

def get_frequency(text):
    return Counter(text.split()).most_common()

# %%
int_nonqa = {} # key = userID, value = description  
ext_nonqa_twitter = {} # key = userID, value = description
ext_nonqa_hp = {} # key = userID, value = description

import re
#About
p=re.compile(r'&lt;(\S)*|p&gt;|\&#xA;|&quot;|/a&gt;|/li&gt;|/ul&gt;|/b&gt;|&gt;|;|#\d(\d)+|&amp')
a = open('user_internal_nonqa_info.txt')
for line in a:
    tmp=p.sub('', line) #remove all punctuations in i(single sentence) and store in tmp
    list_line = tmp.split('\t')
    int_nonqa[list_line[0]] = list_line[3]

#Twitter
a = open('user_external_nonqa_info.txt')
for line in a:
    list_line = line.split('\t')
    ext_nonqa_twitter[list_line[0]] = list_line[1]

#HomePage
a = open('user_external_nonqa_info_homepage_nouns.txt')
for line in a:
    list_line = line.split('\t')
    if(len(list_line) >= 2):
        ext_nonqa_hp[list_line[0]] = list_line[1]
        
        
def get_non_qa(accountid):
    data=""
    if ext_nonqa_hp.get(accountid) is not None:
        data += ext_nonqa_hp[accountid]
    if ext_nonqa_twitter.get(accountid) is not None:
        data += ext_nonqa_twitter[accountid]
    if int_nonqa.get(accountid) is not None:
        data += int_nonqa[accountid]
        
    data = re.sub(r"[\n\t\s]*", "", data)       
    return data

# %% [markdown]
# # 2. Split the data

# %%
questions = {}
ground_truths = {}
time_of_question = {}

#Get each question
for atype in e.findall('row'):
    id=atype.get('PostTypeId')
    if int(id)==1:
        body=atype.get('Body')
        title=atype.get('Title')
        tags=atype.get('Tags')
        que_id=int(atype.get('Id'))
        
        ground_truths[que_id] = get_ground_truth(que_id)
        body = remove_html_tags(body)
        title = remove_html_tags(title)
        tags=clean_tags(tags)
        post=str(body)+" "+str(title)+str(tags)

        questions[que_id] = post
        time_of_question[que_id] = get_epoch(atype.get('CreationDate'))
l=len(questions)

index=int(l*0.8)

#split
train_questions=dict(questions.items()[:index])
test_questions=dict(questions.items()[index:])
print(len(train_questions),len(test_questions))


#writing data to file
train_file_name = './stage/question_meta_train.txt'
test_file_name = './stage/question_meta_test.txt'

questions = train_questions.values()
train_handler = open(train_file_name, 'w')
test_handler = open(test_file_name, 'w')

train_list = []
test_list = []
len_list = len(questions)
for i in range(len_list):
    if i < 3*len_list/4:
        train_list.append(questions[i])
    else:
        test_list.append(questions[i])
        
train_handler.write("\n".join(train_list))
test_handler.write("\n".join(test_list))

train_handler.close()
test_handler.close()

print 'Done creating train and test data'
# Out:
# (692, 174)
# Done creating train and test data

# %% [markdown]
# # Training Doc2Vec on the questions

# %%
import gensim.models as g
import logging

#doc2vec parameters
vector_size = 300
window_size = 15
min_count = 1
sampling_threshold = 1e-5
negative_size = 5
train_epoch = 100
dm = 0 #0 = dbow; 1 = dmpv
worker_count = 1 #number of parallel processes

# %%
#input corpus
train_corpus = train_file_name

#output model
saved_path = "./stage/doc2vec_model.bin"

#enable logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

#train doc2vec model
docs = g.doc2vec.TaggedLineDocument(train_corpus)
model = g.Doc2Vec(docs, size=vector_size, window=window_size, min_count=min_count, sample=sampling_threshold, workers=worker_count, hs=0, dm=dm, negative=negative_size, dbow_words=1, dm_concat=1, iter=train_epoch)
# Out:
# /usr/local/lib/python2.7/dist-packages/gensim/models/doc2vec.py:362: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# /usr/local/lib/python2.7/dist-packages/gensim/models/doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 2018-04-18 13:01:29,984 : INFO : collecting all words and their counts
# 2018-04-18 13:01:29,986 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2018-04-18 13:01:30,031 : INFO : collected 10119 word types and 519 unique tags from a corpus of 519 examples and 62863 words
# 2018-04-18 13:01:30,033 : INFO : Loading a fresh vocabulary
# 2018-04-18 13:01:30,070 : INFO : min_count=1 retains 10119 unique words (100% of original 10119, drops 0)
# 2018-04-18 13:01:30,071 : INFO : min_count=1 leaves 62863 word corpus (100% of original 62863, drops 0)
# 2018-04-18 13:01:30,114 : INFO : deleting the raw counts dictionary of 10119 items
# 2018-04-18 13:01:30,116 : INFO : sample=1e-05 downsamples 4018 most-common words
# 2018-04-18 13:01:30,118 : INFO : downsampling leaves estimated 16967 word corpus (27.0% of prior 62863)
# 2018-04-18 13:01:30,161 : INFO : estimated required memory for 10119 words and 300 dimensions: 29967900 bytes
# 2018-04-18 13:01:30,162 : INFO : resetting layer weights
# 2018-04-18 13:01:30,308 : INFO : training model with 1 workers on 10120 vocabulary and 300 features, using sg=1 hs=0 sample=1e-05 negative=5 window=15
# 2018-04-18 13:01:30,810 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:30,811 : INFO : EPOCH - 1 : training on 62863 raw words (17566 effective words) took 0.5s, 35148 effective words/s
# 2018-04-18 13:01:31,296 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:31,298 : INFO : EPOCH - 2 : training on 62863 raw words (17458 effective words) took 0.5s, 35970 effective words/s
# 2018-04-18 13:01:31,689 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:31,690 : INFO : EPOCH - 3 : training on 62863 raw words (17383 effective words) took 0.4s, 44559 effective words/s
# 2018-04-18 13:01:32,118 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:32,119 : INFO : EPOCH - 4 : training on 62863 raw words (17536 effective words) took 0.4s, 41076 effective words/s
# 2018-04-18 13:01:32,490 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:32,492 : INFO : EPOCH - 5 : training on 62863 raw words (17531 effective words) took 0.4s, 47242 effective words/s
# 2018-04-18 13:01:32,863 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:32,865 : INFO : EPOCH - 6 : training on 62863 raw words (17437 effective words) took 0.4s, 46957 effective words/s
# 2018-04-18 13:01:33,235 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:33,236 : INFO : EPOCH - 7 : training on 62863 raw words (17477 effective words) took 0.4s, 47302 effective words/s
# 2018-04-18 13:01:33,600 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:33,602 : INFO : EPOCH - 8 : training on 62863 raw words (17475 effective words) took 0.4s, 48129 effective words/s
# 2018-04-18 13:01:33,972 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:33,973 : INFO : EPOCH - 9 : training on 62863 raw words (17525 effective words) took 0.4s, 47457 effective words/s
# 2018-04-18 13:01:34,346 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:34,347 : INFO : EPOCH - 10 : training on 62863 raw words (17419 effective words) took 0.4s, 46778 effective words/s
# 2018-04-18 13:01:34,754 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:34,756 : INFO : EPOCH - 11 : training on 62863 raw words (17518 effective words) took 0.4s, 43122 effective words/s
# 2018-04-18 13:01:35,192 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:35,193 : INFO : EPOCH - 12 : training on 62863 raw words (17336 effective words) took 0.4s, 39848 effective words/s
# 2018-04-18 13:01:35,586 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:35,587 : INFO : EPOCH - 13 : training on 62863 raw words (17544 effective words) took 0.4s, 44722 effective words/s
# 2018-04-18 13:01:35,970 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:35,972 : INFO : EPOCH - 14 : training on 62863 raw words (17415 effective words) took 0.4s, 45573 effective words/s
# 2018-04-18 13:01:36,403 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:36,404 : INFO : EPOCH - 15 : training on 62863 raw words (17430 effective words) took 0.4s, 40445 effective words/s
# 2018-04-18 13:01:36,778 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:36,779 : INFO : EPOCH - 16 : training on 62863 raw words (17445 effective words) took 0.4s, 46746 effective words/s
# 2018-04-18 13:01:37,153 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:37,154 : INFO : EPOCH - 17 : training on 62863 raw words (17348 effective words) took 0.4s, 46518 effective words/s
# 2018-04-18 13:01:37,541 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:37,543 : INFO : EPOCH - 18 : training on 62863 raw words (17482 effective words) took 0.4s, 45207 effective words/s
# 2018-04-18 13:01:37,926 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:37,927 : INFO : EPOCH - 19 : training on 62863 raw words (17496 effective words) took 0.4s, 45783 effective words/s
# 2018-04-18 13:01:38,292 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:38,294 : INFO : EPOCH - 20 : training on 62863 raw words (17484 effective words) took 0.4s, 47949 effective words/s
# 2018-04-18 13:01:38,738 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:38,740 : INFO : EPOCH - 21 : training on 62863 raw words (17498 effective words) took 0.4s, 39408 effective words/s
# 2018-04-18 13:01:39,137 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:39,139 : INFO : EPOCH - 22 : training on 62863 raw words (17582 effective words) took 0.4s, 44319 effective words/s
# 2018-04-18 13:01:39,576 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:39,578 : INFO : EPOCH - 23 : training on 62863 raw words (17505 effective words) took 0.4s, 40075 effective words/s
# 2018-04-18 13:01:39,987 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:39,989 : INFO : EPOCH - 24 : training on 62863 raw words (17518 effective words) took 0.4s, 42808 effective words/s
# 2018-04-18 13:01:40,376 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:40,377 : INFO : EPOCH - 25 : training on 62863 raw words (17402 effective words) took 0.4s, 45060 effective words/s
# 2018-04-18 13:01:40,821 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:40,822 : INFO : EPOCH - 26 : training on 62863 raw words (17444 effective words) took 0.4s, 39670 effective words/s
# 2018-04-18 13:01:41,331 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:41,333 : INFO : EPOCH - 27 : training on 62863 raw words (17469 effective words) took 0.5s, 34395 effective words/s
# 2018-04-18 13:01:41,797 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:41,798 : INFO : EPOCH - 28 : training on 62863 raw words (17521 effective words) took 0.5s, 37810 effective words/s
# 2018-04-18 13:01:42,222 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:42,223 : INFO : EPOCH - 29 : training on 62863 raw words (17419 effective words) took 0.4s, 41173 effective words/s
# 2018-04-18 13:01:42,671 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:42,672 : INFO : EPOCH - 30 : training on 62863 raw words (17607 effective words) took 0.4s, 39399 effective words/s
# 2018-04-18 13:01:43,125 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:43,127 : INFO : EPOCH - 31 : training on 62863 raw words (17481 effective words) took 0.5s, 38573 effective words/s
# 2018-04-18 13:01:43,508 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:43,509 : INFO : EPOCH - 32 : training on 62863 raw words (17477 effective words) took 0.4s, 45939 effective words/s
# 2018-04-18 13:01:43,971 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:43,973 : INFO : EPOCH - 33 : training on 62863 raw words (17421 effective words) took 0.5s, 37743 effective words/s
# 2018-04-18 13:01:44,352 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:44,354 : INFO : EPOCH - 34 : training on 62863 raw words (17541 effective words) took 0.4s, 46329 effective words/s
# 2018-04-18 13:01:44,794 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:44,796 : INFO : EPOCH - 35 : training on 62863 raw words (17474 effective words) took 0.4s, 39744 effective words/s
# 2018-04-18 13:01:45,384 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:45,386 : INFO : EPOCH - 36 : training on 62863 raw words (17414 effective words) took 0.6s, 29636 effective words/s
# 2018-04-18 13:01:45,874 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:45,875 : INFO : EPOCH - 37 : training on 62863 raw words (17397 effective words) took 0.5s, 35731 effective words/s
# 2018-04-18 13:01:46,338 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:46,340 : INFO : EPOCH - 38 : training on 62863 raw words (17457 effective words) took 0.5s, 37993 effective words/s
# 2018-04-18 13:01:46,795 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:46,796 : INFO : EPOCH - 39 : training on 62863 raw words (17519 effective words) took 0.5s, 38742 effective words/s
# 2018-04-18 13:01:47,187 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:47,188 : INFO : EPOCH - 40 : training on 62863 raw words (17501 effective words) took 0.4s, 44826 effective words/s
# 2018-04-18 13:01:47,562 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:47,564 : INFO : EPOCH - 41 : training on 62863 raw words (17451 effective words) took 0.4s, 46648 effective words/s
# 2018-04-18 13:01:47,936 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:47,937 : INFO : EPOCH - 42 : training on 62863 raw words (17527 effective words) took 0.4s, 47165 effective words/s
# 2018-04-18 13:01:48,412 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:48,413 : INFO : EPOCH - 43 : training on 62863 raw words (17503 effective words) took 0.5s, 36930 effective words/s
# 2018-04-18 13:01:48,868 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:48,869 : INFO : EPOCH - 44 : training on 62863 raw words (17387 effective words) took 0.5s, 38319 effective words/s
# 2018-04-18 13:01:49,312 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:49,313 : INFO : EPOCH - 45 : training on 62863 raw words (17325 effective words) took 0.4s, 39191 effective words/s
# 2018-04-18 13:01:49,757 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:49,758 : INFO : EPOCH - 46 : training on 62863 raw words (17425 effective words) took 0.4s, 39332 effective words/s
# 2018-04-18 13:01:50,205 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:50,206 : INFO : EPOCH - 47 : training on 62863 raw words (17525 effective words) took 0.4s, 39289 effective words/s
# 2018-04-18 13:01:50,572 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:50,573 : INFO : EPOCH - 48 : training on 62863 raw words (17470 effective words) took 0.4s, 47927 effective words/s
# 2018-04-18 13:01:50,961 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:50,963 : INFO : EPOCH - 49 : training on 62863 raw words (17432 effective words) took 0.4s, 44978 effective words/s
# 2018-04-18 13:01:51,331 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:51,332 : INFO : EPOCH - 50 : training on 62863 raw words (17364 effective words) took 0.4s, 47217 effective words/s
# 2018-04-18 13:01:51,774 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:51,775 : INFO : EPOCH - 51 : training on 62863 raw words (17553 effective words) took 0.4s, 39798 effective words/s
# 2018-04-18 13:01:52,216 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:52,218 : INFO : EPOCH - 52 : training on 62863 raw words (17573 effective words) took 0.4s, 39936 effective words/s
# 2018-04-18 13:01:52,649 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:52,651 : INFO : EPOCH - 53 : training on 62863 raw words (17395 effective words) took 0.4s, 40355 effective words/s
# 2018-04-18 13:01:53,038 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:53,039 : INFO : EPOCH - 54 : training on 62863 raw words (17572 effective words) took 0.4s, 45519 effective words/s
# 2018-04-18 13:01:53,477 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:53,478 : INFO : EPOCH - 55 : training on 62863 raw words (17502 effective words) took 0.4s, 40065 effective words/s
# 2018-04-18 13:01:53,881 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:53,882 : INFO : EPOCH - 56 : training on 62863 raw words (17290 effective words) took 0.4s, 42999 effective words/s
# 2018-04-18 13:01:54,365 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:54,367 : INFO : EPOCH - 57 : training on 62863 raw words (17639 effective words) took 0.5s, 36593 effective words/s
# 2018-04-18 13:01:54,801 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:54,802 : INFO : EPOCH - 58 : training on 62863 raw words (17563 effective words) took 0.4s, 40516 effective words/s
# 2018-04-18 13:01:55,207 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:55,209 : INFO : EPOCH - 59 : training on 62863 raw words (17414 effective words) took 0.4s, 43050 effective words/s
# 2018-04-18 13:01:55,642 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:55,643 : INFO : EPOCH - 60 : training on 62863 raw words (17459 effective words) took 0.4s, 40387 effective words/s
# 2018-04-18 13:01:56,176 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:56,177 : INFO : EPOCH - 61 : training on 62863 raw words (17524 effective words) took 0.5s, 32947 effective words/s
# 2018-04-18 13:01:56,615 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:56,616 : INFO : EPOCH - 62 : training on 62863 raw words (17442 effective words) took 0.4s, 39929 effective words/s
# 2018-04-18 13:01:57,016 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:57,018 : INFO : EPOCH - 63 : training on 62863 raw words (17579 effective words) took 0.4s, 43993 effective words/s
# 2018-04-18 13:01:57,376 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:57,378 : INFO : EPOCH - 64 : training on 62863 raw words (17550 effective words) took 0.4s, 49084 effective words/s
# 2018-04-18 13:01:57,740 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:57,742 : INFO : EPOCH - 65 : training on 62863 raw words (17481 effective words) took 0.4s, 48282 effective words/s
# 2018-04-18 13:01:58,282 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:58,284 : INFO : EPOCH - 66 : training on 62863 raw words (17507 effective words) took 0.5s, 32408 effective words/s
# 2018-04-18 13:01:58,745 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:58,747 : INFO : EPOCH - 67 : training on 62863 raw words (17452 effective words) took 0.5s, 37870 effective words/s
# 2018-04-18 13:01:59,192 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:59,193 : INFO : EPOCH - 68 : training on 62863 raw words (17375 effective words) took 0.4s, 39190 effective words/s
# 2018-04-18 13:01:59,681 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:01:59,683 : INFO : EPOCH - 69 : training on 62863 raw words (17520 effective words) took 0.5s, 35930 effective words/s
# 2018-04-18 13:02:00,105 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:00,107 : INFO : EPOCH - 70 : training on 62863 raw words (17445 effective words) took 0.4s, 41263 effective words/s
# 2018-04-18 13:02:00,566 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:00,568 : INFO : EPOCH - 71 : training on 62863 raw words (17500 effective words) took 0.5s, 38147 effective words/s
# 2018-04-18 13:02:01,031 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:01,032 : INFO : EPOCH - 72 : training on 62863 raw words (17487 effective words) took 0.5s, 37783 effective words/s
# 2018-04-18 13:02:01,479 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:01,480 : INFO : EPOCH - 73 : training on 62863 raw words (17553 effective words) took 0.4s, 39364 effective words/s
# 2018-04-18 13:02:01,842 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:01,844 : INFO : EPOCH - 74 : training on 62863 raw words (17376 effective words) took 0.4s, 48062 effective words/s
# 2018-04-18 13:02:02,324 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:02,326 : INFO : EPOCH - 75 : training on 62863 raw words (17500 effective words) took 0.5s, 36806 effective words/s
# 2018-04-18 13:02:02,786 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:02,787 : INFO : EPOCH - 76 : training on 62863 raw words (17468 effective words) took 0.5s, 38031 effective words/s
# 2018-04-18 13:02:03,211 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:03,212 : INFO : EPOCH - 77 : training on 62863 raw words (17366 effective words) took 0.4s, 41070 effective words/s
# 2018-04-18 13:02:03,640 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:03,641 : INFO : EPOCH - 78 : training on 62863 raw words (17556 effective words) took 0.4s, 41153 effective words/s
# 2018-04-18 13:02:04,202 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:04,203 : INFO : EPOCH - 79 : training on 62863 raw words (17481 effective words) took 0.6s, 31193 effective words/s
# 2018-04-18 13:02:04,634 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:04,636 : INFO : EPOCH - 80 : training on 62863 raw words (17513 effective words) took 0.4s, 40737 effective words/s
# 2018-04-18 13:02:05,103 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:05,105 : INFO : EPOCH - 81 : training on 62863 raw words (17467 effective words) took 0.5s, 37443 effective words/s
# 2018-04-18 13:02:05,516 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:05,518 : INFO : EPOCH - 82 : training on 62863 raw words (17412 effective words) took 0.4s, 42314 effective words/s
# 2018-04-18 13:02:05,961 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:05,963 : INFO : EPOCH - 83 : training on 62863 raw words (17482 effective words) took 0.4s, 39977 effective words/s
# 2018-04-18 13:02:06,434 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:06,435 : INFO : EPOCH - 84 : training on 62863 raw words (17517 effective words) took 0.5s, 37280 effective words/s
# 2018-04-18 13:02:06,803 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:06,804 : INFO : EPOCH - 85 : training on 62863 raw words (17446 effective words) took 0.4s, 47446 effective words/s
# 2018-04-18 13:02:07,236 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:07,238 : INFO : EPOCH - 86 : training on 62863 raw words (17452 effective words) took 0.4s, 40419 effective words/s
# 2018-04-18 13:02:07,682 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:07,683 : INFO : EPOCH - 87 : training on 62863 raw words (17529 effective words) took 0.4s, 39497 effective words/s
# 2018-04-18 13:02:08,137 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:08,139 : INFO : EPOCH - 88 : training on 62863 raw words (17551 effective words) took 0.5s, 38670 effective words/s
# 2018-04-18 13:02:08,544 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:08,545 : INFO : EPOCH - 89 : training on 62863 raw words (17462 effective words) took 0.4s, 43149 effective words/s
# 2018-04-18 13:02:08,922 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:08,924 : INFO : EPOCH - 90 : training on 62863 raw words (17580 effective words) took 0.4s, 46718 effective words/s
# 2018-04-18 13:02:09,381 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:09,383 : INFO : EPOCH - 91 : training on 62863 raw words (17353 effective words) took 0.5s, 37978 effective words/s
# 2018-04-18 13:02:09,778 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:09,780 : INFO : EPOCH - 92 : training on 62863 raw words (17418 effective words) took 0.4s, 44100 effective words/s
# 2018-04-18 13:02:10,212 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:10,213 : INFO : EPOCH - 93 : training on 62863 raw words (17579 effective words) took 0.4s, 40778 effective words/s
# 2018-04-18 13:02:10,583 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:10,585 : INFO : EPOCH - 94 : training on 62863 raw words (17436 effective words) took 0.4s, 47206 effective words/s
# 2018-04-18 13:02:10,998 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:11,000 : INFO : EPOCH - 95 : training on 62863 raw words (17463 effective words) took 0.4s, 42319 effective words/s
# 2018-04-18 13:02:11,370 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:11,372 : INFO : EPOCH - 96 : training on 62863 raw words (17480 effective words) took 0.4s, 47302 effective words/s
# 2018-04-18 13:02:11,809 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:11,810 : INFO : EPOCH - 97 : training on 62863 raw words (17682 effective words) took 0.4s, 40514 effective words/s
# 2018-04-18 13:02:12,236 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:12,238 : INFO : EPOCH - 98 : training on 62863 raw words (17430 effective words) took 0.4s, 40968 effective words/s
# 2018-04-18 13:02:12,602 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:12,604 : INFO : EPOCH - 99 : training on 62863 raw words (17431 effective words) took 0.4s, 47863 effective words/s
# 2018-04-18 13:02:12,965 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 13:02:12,966 : INFO : EPOCH - 100 : training on 62863 raw words (17496 effective words) took 0.4s, 48500 effective words/s
# 2018-04-18 13:02:12,968 : INFO : training on a 6286300 raw words (1747662 effective words) took 42.7s, 40970 effective words/s

# %% [markdown]
# ## Getting the Doc2Vec vectors for all the users based on their previous questions

# %%
import pickle
pickle_file = './stage/user_vectors_qa.pkl'
try:
    user_vector = pickle.load(open(pickle_file, 'rb'))
except (OSError, IOError) as error:
    print error
    #inference hyper-parameters
    start_alpha=0.01
    infer_epoch=1000

    post_by_user = {}
    user_vector = {}
    for users_row in u.findall('row'):
        user_id = users_row.get('Id')
        AccountId = users_row.get('AccountId')
#         post_by_user[int(user_id)] = get_posts(user_id)[0] + str(get_non_qa(AccountId))
        post_by_user[int(user_id)] = get_posts(user_id)[0]
#         post_by_user[int(user_id)] = get_non_qa(AccountId)

        user_vector[int(user_id)] = model.infer_vector(post_by_user[int(user_id)], alpha=start_alpha, steps=infer_epoch)
    pickle.dump(user_vector, open(pickle_file, 'wb'))

# %% [markdown]
# ## Infering

# %%
def calculate_MRR_per_qn(pred, actual):
    for i, p in enumerate(pred):
        if(p in actual):
            return (1./(i+1))
    return 0

def calculate_precision_per_qn(pred, actual):
    n_common_items = len(set(pred) - (set(pred) - set(actual)))
    return (n_common_items * 1.) / len(pred)

# %%
import numpy as np
import numpy.linalg as lin
import operator
start_alpha=0.01
infer_epoch=1000
mrr_s = []
precision_s_5 = []
precision_s_10 = []
user_id_question_map = {}

for que_id in test_questions.keys():
    userids = []
    userids_5 = []
    test_questions[que_id]
    vector = model.infer_vector(test_questions[que_id], alpha=start_alpha, steps=infer_epoch)
    complete_list = sorted(user_vector.items(), key=lambda (_, v): lin.norm(map(operator.sub, v,  vector), ord=2))
    
    for item in complete_list[:10]:
        userids.append(item[0])
    for item in complete_list[:5]:
        userids_5.append(item[0])
    
    mrr_s.append(calculate_MRR_per_qn(userids, ground_truths[que_id]))
    precision_s_10.append(calculate_precision_per_qn(userids, ground_truths[que_id]))
    precision_s_5.append(calculate_precision_per_qn(userids_5, ground_truths[que_id]))
    
    user_id_question_map[que_id] = complete_list
    print ('(current)Mean Reciprocal Rank: ', np.mean(mrr_s))
    print ('(current)Precision @ 5', np.mean(precision_s_5))
    print ('(current)Precision @ 10', np.mean(precision_s_10))

    print ('\n')
    
mrr = np.mean(mrr_s)
prec_5 = np.mean(precision_s_5)
prec_10 = np.mean(precision_s_10)

print ('(final)Mean Reciprocal Rank: ', mrr)
print ('(final)Precision @ 5', prec_5)
print ('(final)Precision @ 10', prec_10)
# Out:
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0)
# ('(current)Precision @ 5', 0.0)
# ('(current)Precision @ 10', 0.0)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.1111111111111111)
# ('(current)Precision @ 5', 0.022222222222222223)
# ('(current)Precision @ 10', 0.011111111111111112)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.2)
# ('(current)Precision @ 5', 0.04)
# ('(current)Precision @ 10', 0.02)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.18181818181818182)
# ('(current)Precision @ 5', 0.03636363636363637)
# ('(current)Precision @ 10', 0.018181818181818184)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.16666666666666666)
# ('(current)Precision @ 5', 0.03333333333333333)
# ('(current)Precision @ 10', 0.016666666666666666)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.15384615384615385)
# ('(current)Precision @ 5', 0.03076923076923077)
# ('(current)Precision @ 10', 0.015384615384615385)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.14285714285714285)
# ('(current)Precision @ 5', 0.028571428571428574)
# ('(current)Precision @ 10', 0.014285714285714287)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.13333333333333333)
# ('(current)Precision @ 5', 0.02666666666666667)
# ('(current)Precision @ 10', 0.013333333333333334)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.125)
# ('(current)Precision @ 5', 0.025)
# ('(current)Precision @ 10', 0.0125)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.11764705882352941)
# ('(current)Precision @ 5', 0.023529411764705882)
# ('(current)Precision @ 10', 0.011764705882352941)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.1111111111111111)
# ('(current)Precision @ 5', 0.022222222222222223)
# ('(current)Precision @ 10', 0.011111111111111112)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.10526315789473684)
# ('(current)Precision @ 5', 0.021052631578947368)
# ('(current)Precision @ 10', 0.010526315789473684)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.1)
# ('(current)Precision @ 5', 0.02)
# ('(current)Precision @ 10', 0.01)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.09523809523809523)
# ('(current)Precision @ 5', 0.01904761904761905)
# ('(current)Precision @ 10', 0.009523809523809525)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.09090909090909091)
# ('(current)Precision @ 5', 0.018181818181818184)
# ('(current)Precision @ 10', 0.009090909090909092)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.08695652173913043)
# ('(current)Precision @ 5', 0.017391304347826087)
# ('(current)Precision @ 10', 0.008695652173913044)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.08333333333333333)
# ('(current)Precision @ 5', 0.016666666666666666)
# ('(current)Precision @ 10', 0.008333333333333333)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.08)
# ('(current)Precision @ 5', 0.016)
# ('(current)Precision @ 10', 0.008)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.07692307692307693)
# ('(current)Precision @ 5', 0.015384615384615385)
# ('(current)Precision @ 10', 0.007692307692307693)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.07407407407407407)
# ('(current)Precision @ 5', 0.014814814814814815)
# ('(current)Precision @ 10', 0.007407407407407408)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.07142857142857142)
# ('(current)Precision @ 5', 0.014285714285714287)
# ('(current)Precision @ 10', 0.0071428571428571435)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.06896551724137931)
# ('(current)Precision @ 5', 0.013793103448275864)
# ('(current)Precision @ 10', 0.006896551724137932)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.06666666666666667)
# ('(current)Precision @ 5', 0.013333333333333334)
# ('(current)Precision @ 10', 0.006666666666666667)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.06451612903225806)
# ('(current)Precision @ 5', 0.012903225806451613)
# ('(current)Precision @ 10', 0.0064516129032258064)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0625)
# ('(current)Precision @ 5', 0.0125)
# ('(current)Precision @ 10', 0.00625)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.06060606060606061)
# ('(current)Precision @ 5', 0.012121212121212121)
# ('(current)Precision @ 10', 0.006060606060606061)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.058823529411764705)
# ('(current)Precision @ 5', 0.011764705882352941)
# ('(current)Precision @ 10', 0.0058823529411764705)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.05714285714285714)
# ('(current)Precision @ 5', 0.011428571428571429)
# ('(current)Precision @ 10', 0.005714285714285714)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.05555555555555555)
# ('(current)Precision @ 5', 0.011111111111111112)
# ('(current)Precision @ 10', 0.005555555555555556)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.05405405405405406)
# ('(current)Precision @ 5', 0.010810810810810811)
# ('(current)Precision @ 10', 0.005405405405405406)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.05263157894736842)
# ('(current)Precision @ 5', 0.010526315789473684)
# ('(current)Precision @ 10', 0.005263157894736842)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.05128205128205128)
# ('(current)Precision @ 5', 0.010256410256410256)
# ('(current)Precision @ 10', 0.005128205128205128)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.05)
# ('(current)Precision @ 5', 0.01)
# ('(current)Precision @ 10', 0.005)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04878048780487805)
# ('(current)Precision @ 5', 0.00975609756097561)
# ('(current)Precision @ 10', 0.004878048780487805)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.047619047619047616)
# ('(current)Precision @ 5', 0.009523809523809525)
# ('(current)Precision @ 10', 0.004761904761904762)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.046511627906976744)
# ('(current)Precision @ 5', 0.009302325581395349)
# ('(current)Precision @ 10', 0.004651162790697674)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.045454545454545456)
# ('(current)Precision @ 5', 0.009090909090909092)
# ('(current)Precision @ 10', 0.004545454545454546)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.044444444444444446)
# ('(current)Precision @ 5', 0.008888888888888889)
# ('(current)Precision @ 10', 0.0044444444444444444)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.043478260869565216)
# ('(current)Precision @ 5', 0.008695652173913044)
# ('(current)Precision @ 10', 0.004347826086956522)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0425531914893617)
# ('(current)Precision @ 5', 0.00851063829787234)
# ('(current)Precision @ 10', 0.00425531914893617)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.041666666666666664)
# ('(current)Precision @ 5', 0.008333333333333333)
# ('(current)Precision @ 10', 0.004166666666666667)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04081632653061224)
# ('(current)Precision @ 5', 0.00816326530612245)
# ('(current)Precision @ 10', 0.004081632653061225)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04)
# ('(current)Precision @ 5', 0.008)
# ('(current)Precision @ 10', 0.004)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0392156862745098)
# ('(current)Precision @ 5', 0.00784313725490196)
# ('(current)Precision @ 10', 0.00392156862745098)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.038461538461538464)
# ('(current)Precision @ 5', 0.007692307692307693)
# ('(current)Precision @ 10', 0.0038461538461538464)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03773584905660377)
# ('(current)Precision @ 5', 0.007547169811320755)
# ('(current)Precision @ 10', 0.0037735849056603774)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.037037037037037035)
# ('(current)Precision @ 5', 0.007407407407407408)
# ('(current)Precision @ 10', 0.003703703703703704)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03636363636363636)
# ('(current)Precision @ 5', 0.007272727272727273)
# ('(current)Precision @ 10', 0.0036363636363636364)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03571428571428571)
# ('(current)Precision @ 5', 0.0071428571428571435)
# ('(current)Precision @ 10', 0.0035714285714285718)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03508771929824561)
# ('(current)Precision @ 5', 0.007017543859649123)
# ('(current)Precision @ 10', 0.0035087719298245615)
# ('(current)Mean Reciprocal Rank: ', 0.034482758620689655)
# ('(current)Precision @ 5', 0.006896551724137932)
# ('(current)Precision @ 10', 0.003448275862068966)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03389830508474576)
# ('(current)Precision @ 5', 0.006779661016949153)
# ('(current)Precision @ 10', 0.0033898305084745766)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03333333333333333)
# ('(current)Precision @ 5', 0.006666666666666667)
# ('(current)Precision @ 10', 0.0033333333333333335)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03278688524590164)
# ('(current)Precision @ 5', 0.006557377049180328)
# ('(current)Precision @ 10', 0.003278688524590164)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03225806451612903)
# ('(current)Precision @ 5', 0.0064516129032258064)
# ('(current)Precision @ 10', 0.0032258064516129032)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.031746031746031744)
# ('(current)Precision @ 5', 0.006349206349206349)
# ('(current)Precision @ 10', 0.0031746031746031746)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03125)
# ('(current)Precision @ 5', 0.00625)
# ('(current)Precision @ 10', 0.003125)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03076923076923077)
# ('(current)Precision @ 5', 0.006153846153846154)
# ('(current)Precision @ 10', 0.003076923076923077)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.030303030303030304)
# ('(current)Precision @ 5', 0.006060606060606061)
# ('(current)Precision @ 10', 0.0030303030303030303)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.029850746268656716)
# ('(current)Precision @ 5', 0.005970149253731343)
# ('(current)Precision @ 10', 0.0029850746268656717)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.029411764705882353)
# ('(current)Precision @ 5', 0.0058823529411764705)
# ('(current)Precision @ 10', 0.0029411764705882353)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.028985507246376812)
# ('(current)Precision @ 5', 0.005797101449275362)
# ('(current)Precision @ 10', 0.002898550724637681)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.02857142857142857)
# ('(current)Precision @ 5', 0.005714285714285714)
# ('(current)Precision @ 10', 0.002857142857142857)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.028169014084507043)
# ('(current)Precision @ 5', 0.005633802816901409)
# ('(current)Precision @ 10', 0.0028169014084507044)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.027777777777777776)
# ('(current)Precision @ 5', 0.005555555555555556)
# ('(current)Precision @ 10', 0.002777777777777778)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0410958904109589)
# ('(current)Precision @ 5', 0.008219178082191782)
# ('(current)Precision @ 10', 0.004109589041095891)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04054054054054054)
# ('(current)Precision @ 5', 0.008108108108108109)
# ('(current)Precision @ 10', 0.004054054054054054)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04)
# ('(current)Precision @ 5', 0.008000000000000002)
# ('(current)Precision @ 10', 0.004000000000000001)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.039473684210526314)
# ('(current)Precision @ 5', 0.007894736842105265)
# ('(current)Precision @ 10', 0.003947368421052633)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03896103896103896)
# ('(current)Precision @ 5', 0.007792207792207793)
# ('(current)Precision @ 10', 0.0038961038961038965)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.038461538461538464)
# ('(current)Precision @ 5', 0.007692307692307694)
# ('(current)Precision @ 10', 0.003846153846153847)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0379746835443038)
# ('(current)Precision @ 5', 0.007594936708860761)
# ('(current)Precision @ 10', 0.0037974683544303805)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0375)
# ('(current)Precision @ 5', 0.0075000000000000015)
# ('(current)Precision @ 10', 0.0037500000000000007)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.037037037037037035)
# ('(current)Precision @ 5', 0.0074074074074074086)
# ('(current)Precision @ 10', 0.0037037037037037043)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.036585365853658534)
# ('(current)Precision @ 5', 0.007317073170731709)
# ('(current)Precision @ 10', 0.0036585365853658543)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04819277108433735)
# ('(current)Precision @ 5', 0.00963855421686747)
# ('(current)Precision @ 10', 0.004819277108433735)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.047619047619047616)
# ('(current)Precision @ 5', 0.009523809523809525)
# ('(current)Precision @ 10', 0.004761904761904762)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.047058823529411764)
# ('(current)Precision @ 5', 0.009411764705882354)
# ('(current)Precision @ 10', 0.004705882352941177)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.046511627906976744)
# ('(current)Precision @ 5', 0.009302325581395349)
# ('(current)Precision @ 10', 0.004651162790697674)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04597701149425287)
# ('(current)Precision @ 5', 0.009195402298850575)
# ('(current)Precision @ 10', 0.004597701149425287)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.045454545454545456)
# ('(current)Precision @ 5', 0.009090909090909092)
# ('(current)Precision @ 10', 0.004545454545454546)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0449438202247191)
# ('(current)Precision @ 5', 0.008988764044943821)
# ('(current)Precision @ 10', 0.0044943820224719105)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.044444444444444446)
# ('(current)Precision @ 5', 0.008888888888888889)
# ('(current)Precision @ 10', 0.0044444444444444444)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04395604395604396)
# ('(current)Precision @ 5', 0.008791208791208791)
# ('(current)Precision @ 10', 0.004395604395604396)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.043478260869565216)
# ('(current)Precision @ 5', 0.008695652173913044)
# ('(current)Precision @ 10', 0.004347826086956522)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.043010752688172046)
# ('(current)Precision @ 5', 0.008602150537634409)
# ('(current)Precision @ 10', 0.004301075268817204)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0425531914893617)
# ('(current)Precision @ 5', 0.00851063829787234)
# ('(current)Precision @ 10', 0.00425531914893617)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.042105263157894736)
# ('(current)Precision @ 5', 0.008421052631578947)
# ('(current)Precision @ 10', 0.004210526315789474)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.041666666666666664)
# ('(current)Precision @ 5', 0.008333333333333333)
# ('(current)Precision @ 10', 0.004166666666666667)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.041237113402061855)
# ('(current)Precision @ 5', 0.008247422680412371)
# ('(current)Precision @ 10', 0.004123711340206186)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04081632653061224)
# ('(current)Precision @ 5', 0.00816326530612245)
# ('(current)Precision @ 10', 0.004081632653061225)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04040404040404041)
# ('(current)Precision @ 5', 0.00808080808080808)
# ('(current)Precision @ 10', 0.00404040404040404)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04)
# ('(current)Precision @ 5', 0.008)
# ('(current)Precision @ 10', 0.004)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.039603960396039604)
# ('(current)Precision @ 5', 0.007920792079207921)
# ('(current)Precision @ 10', 0.0039603960396039604)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0392156862745098)
# ('(current)Precision @ 5', 0.00784313725490196)
# ('(current)Precision @ 10', 0.00392156862745098)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.038834951456310676)
# ('(current)Precision @ 5', 0.0077669902912621365)
# ('(current)Precision @ 10', 0.0038834951456310682)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.038461538461538464)
# ('(current)Precision @ 5', 0.007692307692307693)
# ('(current)Precision @ 10', 0.0038461538461538464)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0380952380952381)
# ('(current)Precision @ 5', 0.007619047619047619)
# ('(current)Precision @ 10', 0.0038095238095238095)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03773584905660377)
# ('(current)Precision @ 5', 0.007547169811320755)
# ('(current)Precision @ 10', 0.0037735849056603774)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.037383177570093455)
# ('(current)Precision @ 5', 0.007476635514018692)
# ('(current)Precision @ 10', 0.003738317757009346)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.037037037037037035)
# ('(current)Precision @ 5', 0.007407407407407408)
# ('(current)Precision @ 10', 0.003703703703703704)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03669724770642202)
# ('(current)Precision @ 5', 0.007339449541284404)
# ('(current)Precision @ 10', 0.003669724770642202)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03636363636363636)
# ('(current)Precision @ 5', 0.007272727272727273)
# ('(current)Precision @ 10', 0.0036363636363636364)
# ('(current)Mean Reciprocal Rank: ', 0.036036036036036036)
# ('(current)Precision @ 5', 0.007207207207207207)
# ('(current)Precision @ 10', 0.0036036036036036037)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03571428571428571)
# ('(current)Precision @ 5', 0.0071428571428571435)
# ('(current)Precision @ 10', 0.0035714285714285718)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.035398230088495575)
# ('(current)Precision @ 5', 0.007079646017699116)
# ('(current)Precision @ 10', 0.003539823008849558)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03508771929824561)
# ('(current)Precision @ 5', 0.007017543859649123)
# ('(current)Precision @ 10', 0.0035087719298245615)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.034782608695652174)
# ('(current)Precision @ 5', 0.006956521739130435)
# ('(current)Precision @ 10', 0.0034782608695652175)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.034482758620689655)
# ('(current)Precision @ 5', 0.006896551724137932)
# ('(current)Precision @ 10', 0.003448275862068966)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03418803418803419)
# ('(current)Precision @ 5', 0.006837606837606838)
# ('(current)Precision @ 10', 0.003418803418803419)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03389830508474576)
# ('(current)Precision @ 5', 0.006779661016949153)
# ('(current)Precision @ 10', 0.0033898305084745766)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03361344537815126)
# ('(current)Precision @ 5', 0.0067226890756302525)
# ('(current)Precision @ 10', 0.0033613445378151263)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03333333333333333)
# ('(current)Precision @ 5', 0.006666666666666667)
# ('(current)Precision @ 10', 0.0033333333333333335)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03305785123966942)
# ('(current)Precision @ 5', 0.006611570247933885)
# ('(current)Precision @ 10', 0.0033057851239669425)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03278688524590164)
# ('(current)Precision @ 5', 0.006557377049180328)
# ('(current)Precision @ 10', 0.003278688524590164)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.032520325203252036)
# ('(current)Precision @ 5', 0.0065040650406504065)
# ('(current)Precision @ 10', 0.0032520325203252032)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03225806451612903)
# ('(current)Precision @ 5', 0.0064516129032258064)
# ('(current)Precision @ 10', 0.0032258064516129032)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.032)
# ('(current)Precision @ 5', 0.0064)
# ('(current)Precision @ 10', 0.0032)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.031746031746031744)
# ('(current)Precision @ 5', 0.006349206349206349)
# ('(current)Precision @ 10', 0.0031746031746031746)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.031496062992125984)
# ('(current)Precision @ 5', 0.006299212598425198)
# ('(current)Precision @ 10', 0.003149606299212599)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03125)
# ('(current)Precision @ 5', 0.00625)
# ('(current)Precision @ 10', 0.003125)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.031007751937984496)
# ('(current)Precision @ 5', 0.006201550387596899)
# ('(current)Precision @ 10', 0.0031007751937984496)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03076923076923077)
# ('(current)Precision @ 5', 0.006153846153846154)
# ('(current)Precision @ 10', 0.003076923076923077)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.030534351145038167)
# ('(current)Precision @ 5', 0.0061068702290076335)
# ('(current)Precision @ 10', 0.0030534351145038168)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.030303030303030304)
# ('(current)Precision @ 5', 0.006060606060606061)
# ('(current)Precision @ 10', 0.0030303030303030303)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03007518796992481)
# ('(current)Precision @ 5', 0.006015037593984963)
# ('(current)Precision @ 10', 0.0030075187969924814)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.029850746268656716)
# ('(current)Precision @ 5', 0.005970149253731343)
# ('(current)Precision @ 10', 0.0029850746268656717)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.02962962962962963)
# ('(current)Precision @ 5', 0.0059259259259259265)
# ('(current)Precision @ 10', 0.0029629629629629632)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03676470588235294)
# ('(current)Precision @ 5', 0.007352941176470588)
# ('(current)Precision @ 10', 0.003676470588235294)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0364963503649635)
# ('(current)Precision @ 5', 0.0072992700729927005)
# ('(current)Precision @ 10', 0.0036496350364963502)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.043478260869565216)
# ('(current)Precision @ 5', 0.008695652173913045)
# ('(current)Precision @ 10', 0.004347826086956523)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04316546762589928)
# ('(current)Precision @ 5', 0.008633093525179858)
# ('(current)Precision @ 10', 0.004316546762589929)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04285714285714286)
# ('(current)Precision @ 5', 0.008571428571428572)
# ('(current)Precision @ 10', 0.004285714285714286)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0425531914893617)
# ('(current)Precision @ 5', 0.008510638297872342)
# ('(current)Precision @ 10', 0.004255319148936171)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04225352112676056)
# ('(current)Precision @ 5', 0.008450704225352114)
# ('(current)Precision @ 10', 0.004225352112676057)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04195804195804196)
# ('(current)Precision @ 5', 0.008391608391608393)
# ('(current)Precision @ 10', 0.004195804195804197)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.041666666666666664)
# ('(current)Precision @ 5', 0.008333333333333335)
# ('(current)Precision @ 10', 0.0041666666666666675)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.041379310344827586)
# ('(current)Precision @ 5', 0.00827586206896552)
# ('(current)Precision @ 10', 0.00413793103448276)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0410958904109589)
# ('(current)Precision @ 5', 0.008219178082191782)
# ('(current)Precision @ 10', 0.004109589041095891)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04081632653061224)
# ('(current)Precision @ 5', 0.00816326530612245)
# ('(current)Precision @ 10', 0.004081632653061225)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04054054054054054)
# ('(current)Precision @ 5', 0.008108108108108109)
# ('(current)Precision @ 10', 0.004054054054054054)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.040268456375838924)
# ('(current)Precision @ 5', 0.008053691275167786)
# ('(current)Precision @ 10', 0.004026845637583893)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.04)
# ('(current)Precision @ 5', 0.008000000000000002)
# ('(current)Precision @ 10', 0.004000000000000001)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.039735099337748346)
# ('(current)Precision @ 5', 0.00794701986754967)
# ('(current)Precision @ 10', 0.003973509933774835)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.039473684210526314)
# ('(current)Precision @ 5', 0.007894736842105265)
# ('(current)Precision @ 10', 0.003947368421052633)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0392156862745098)
# ('(current)Precision @ 5', 0.007843137254901962)
# ('(current)Precision @ 10', 0.003921568627450981)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03896103896103896)
# ('(current)Precision @ 5', 0.007792207792207793)
# ('(current)Precision @ 10', 0.0038961038961038965)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03870967741935484)
# ('(current)Precision @ 5', 0.007741935483870969)
# ('(current)Precision @ 10', 0.0038709677419354843)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.038461538461538464)
# ('(current)Precision @ 5', 0.007692307692307694)
# ('(current)Precision @ 10', 0.003846153846153847)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03821656050955414)
# ('(current)Precision @ 5', 0.007643312101910829)
# ('(current)Precision @ 10', 0.0038216560509554145)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0379746835443038)
# ('(current)Precision @ 5', 0.007594936708860761)
# ('(current)Precision @ 10', 0.0037974683544303805)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03773584905660377)
# ('(current)Precision @ 5', 0.007547169811320756)
# ('(current)Precision @ 10', 0.003773584905660378)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.0375)
# ('(current)Precision @ 5', 0.0075000000000000015)
# ('(current)Precision @ 10', 0.0037500000000000007)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.037267080745341616)
# ('(current)Precision @ 5', 0.007453416149068324)
# ('(current)Precision @ 10', 0.003726708074534162)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.037037037037037035)
# ('(current)Precision @ 5', 0.0074074074074074086)
# ('(current)Precision @ 10', 0.0037037037037037043)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03680981595092025)
# ('(current)Precision @ 5', 0.00736196319018405)
# ('(current)Precision @ 10', 0.003680981595092025)
# ('(current)Mean Reciprocal Rank: ', 0.036585365853658534)
# ('(current)Precision @ 5', 0.007317073170731709)
# ('(current)Precision @ 10', 0.0036585365853658543)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03636363636363636)
# ('(current)Precision @ 5', 0.007272727272727274)
# ('(current)Precision @ 10', 0.003636363636363637)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03614457831325301)
# ('(current)Precision @ 5', 0.0072289156626506035)
# ('(current)Precision @ 10', 0.0036144578313253017)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03592814371257485)
# ('(current)Precision @ 5', 0.007185628742514971)
# ('(current)Precision @ 10', 0.0035928143712574854)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03571428571428571)
# ('(current)Precision @ 5', 0.0071428571428571435)
# ('(current)Precision @ 10', 0.0035714285714285718)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03550295857988166)
# ('(current)Precision @ 5', 0.007100591715976333)
# ('(current)Precision @ 10', 0.0035502958579881664)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03529411764705882)
# ('(current)Precision @ 5', 0.007058823529411766)
# ('(current)Precision @ 10', 0.003529411764705883)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03508771929824561)
# ('(current)Precision @ 5', 0.007017543859649124)
# ('(current)Precision @ 10', 0.003508771929824562)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03488372093023256)
# ('(current)Precision @ 5', 0.006976744186046512)
# ('(current)Precision @ 10', 0.003488372093023256)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.03468208092485549)
# ('(current)Precision @ 5', 0.006936416184971099)
# ('(current)Precision @ 10', 0.0034682080924855496)
#
#
# ('(current)Mean Reciprocal Rank: ', 0.034482758620689655)
# ('(current)Precision @ 5', 0.006896551724137932)
# ('(current)Precision @ 10', 0.003448275862068966)
#
#
# ('(final)Mean Reciprocal Rank: ', 0.034482758620689655)
# ('(final)Precision @ 5', 0.006896551724137932)
# ('(final)Precision @ 10', 0.003448275862068966)

# %%
import pickle
pickle_file = './stage/user_id_question_map_doc2vec_qa_p_non_qa.pkl'
pickle.dump(user_id_question_map, open(pickle_file, 'wb'))

# pickle_file = 'groundtruth.pkl'
# pickle.dump(ground_truths, open(pickle_file, 'wb'))
